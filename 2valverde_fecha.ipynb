# %%
import pandas as pd

data = pd.read_csv('new_date.csv')
data
# Out:
#             date  unidad
# 0     2018-01-01       8
# 1     2018-01-02     306
# 2     2018-01-03      88
# 3     2018-01-04     421
# 4     2018-01-05     210
# ...          ...     ...
# 1760  2022-10-27     211
# 1761  2022-10-28     263
# 1762  2022-10-29      28
# 1763  2022-10-30      18
# 1764  2022-10-31      36
#
# [1765 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = data['unidad']
x = data['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
#ax.stem(x, y)
ax.plot(x, y, linewidth=1.0)
ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

ax.xaxis.set_major_locator(dates.MonthLocator())
# 16 is a slight approximation since months differ in number of days.
ax.xaxis.set_minor_locator(dates.MonthLocator(bymonthday=16))

ax.set_ylabel('Unidades')
ax.set_title('Movimiento total')

ax.legend()
plt.grid()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
  
df = data
# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2018 = df.loc[(df['date'] >= '2018-01-01')
                     & (df['date'] < '2019-01-01')]
# Display
df_2018
# Out:
#           date  unidad
# 0   2018-01-01       8
# 1   2018-01-02     306
# 2   2018-01-03      88
# 3   2018-01-04     421
# 4   2018-01-05     210
# ..         ...     ...
# 360 2018-12-27     429
# 361 2018-12-28     129
# 362 2018-12-29       4
# 363 2018-12-30      38
# 364 2018-12-31     189
#
# [365 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2018['unidad']
x = df_2018['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
#ax.stem(x, y)
ax.plot(x, y, linewidth=1.0)
ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

ax.xaxis.set_major_locator(dates.MonthLocator())
# 16 is a slight approximation since months differ in number of days.
ax.xaxis.set_minor_locator(dates.MonthLocator(bymonthday=16))

ax.set_ylabel('Unidades')
ax.set_title('Movimiento 2018')


ax.legend()
plt.grid()
plt.savefig("static\Año 2018.jpg")

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2019-01-01')
                     & (df['date'] < '2020-01-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
#ax.stem(x, y)
ax.plot(x, y, linewidth=1.0)
ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

ax.xaxis.set_major_locator(dates.MonthLocator())
# 16 is a slight approximation since months differ in number of days.
ax.xaxis.set_minor_locator(dates.MonthLocator(bymonthday=16))

ax.set_ylabel('Unidades')
ax.set_title('Movimiento 2019')

ax.legend()
plt.grid()
plt.savefig("static\Año 2019.jpg")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2020-01-01')
                     & (df['date'] < '2021-01-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
#ax.stem(x, y)
ax.plot(x, y, linewidth=1.0)
ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

ax.xaxis.set_major_locator(dates.MonthLocator())
# 16 is a slight approximation since months differ in number of days.
ax.xaxis.set_minor_locator(dates.MonthLocator(bymonthday=16))

ax.set_ylabel('Unidades')
ax.set_title('Movimiento 2020')

ax.legend()
plt.grid()
plt.savefig("static\Año 2020.jpg")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2021-01-01')
                     & (df['date'] < '2022-01-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
#ax.stem(x, y)
ax.plot(x, y, linewidth=1.0)
ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

ax.xaxis.set_major_locator(dates.MonthLocator())
# 16 is a slight approximation since months differ in number of days.
ax.xaxis.set_minor_locator(dates.MonthLocator(bymonthday=16))

ax.set_ylabel('Unidades')
ax.set_title('Movimiento 2021')

ax.legend()
plt.grid()
plt.savefig("static\Año 2021.jpg")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-01-01')
                     & (df['date'] < '2023-01-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
#ax.stem(x, y)
ax.plot(x, y, linewidth=1.0)
ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

ax.xaxis.set_major_locator(dates.MonthLocator())
# 16 is a slight approximation since months differ in number of days.
ax.xaxis.set_minor_locator(dates.MonthLocator(bymonthday=16))

ax.set_ylabel('Unidades')
ax.set_title('Movimiento 2022')

ax.legend()
plt.grid()
plt.savefig("static\Año 2022.jpg")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-01-01')
                     & (df['date'] < '2022-02-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento enero 2022')
plt.savefig("static\enero 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-02-01')
                     & (df['date'] < '2022-03-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento febrero 2022')
plt.savefig("static\\febrero 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-03-01')
                     & (df['date'] < '2022-04-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento marzo 2022')
plt.savefig("static\\marzo 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-04-01')
                     & (df['date'] < '2022-05-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento abril 2022')
plt.savefig("static\\abril 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-05-01')
                     & (df['date'] < '2022-06-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento mayo 2022')
plt.savefig("static\\mayo 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-06-01')
                     & (df['date'] < '2022-07-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento junio 2022')
plt.savefig("static\\junio 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-07-01')
                     & (df['date'] < '2022-08-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento julio 2022')
plt.savefig("static\\julio 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-08-01')
                     & (df['date'] < '2022-09-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento agosto 2022')
plt.savefig("static\\agosto 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-09-01')
                     & (df['date'] < '2022-10-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento septiembre 2022')
plt.savefig("static\\septiembre 2022.jpg")
plt.show()

# %%
import pandas as pd

df = pd.read_csv('new_date.csv')

# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
  
# Filter data between two dates
df_2019 = df.loc[(df['date'] >= '2022-10-01')
                     & (df['date'] < '2022-11-01')]


import matplotlib.pyplot as plt
import matplotlib.dates as dates

y = df_2019['unidad']
x = df_2019['date']
fig, ax = plt.subplots(figsize=(22,12))

#ax.step(x, y, linewidth=1.0)
ax.stem(x, y)

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)

plt.grid()

ax.set_ylabel('Unidades')
ax.set_title('Movimiento octubre 2022')
plt.savefig("static\\octubre 2022.jpg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dates
df = pd.read_csv('new_date.csv')
# Convert the date to datetime64
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')


  
# Filter data between two dates
df_2022 = df.loc[(df['date'] >= '2022-01-01')
                     & (df['date'] < '2023-01-01')]

df_2021 = df.loc[(df['date'] >= '2021-01-01')
                     & (df['date'] < '2022-01-01')]

df_2020 = df.loc[(df['date'] >= '2020-01-01')
                     & (df['date'] < '2021-01-01')]

df_2019 = df.loc[(df['date'] >= '2019-01-01')
                     & (df['date'] < '2020-01-01')]

df_2018 = df.loc[(df['date'] >= '2018-01-01')
                     & (df['date'] < '2019-01-01')]


y = df_2022['unidad']
x = df_2022['date']

y1 = df_2021['unidad']
x1 = df_2021['date']

y2 = df_2020['unidad']
x2 = df_2020['date']

y3 = df_2019['unidad']
x3 = df_2019['date']

y4 = df_2018['unidad']
x4 = df_2018['date']



fig, ax = plt.subplots(figsize=(22,12))


#ax.step(x, y, linewidth=1.0)
#ax.stem(x, y)
ax.plot(x, y, linewidth=1.0 ,label='año 2022')
ax.plot(x1, y1, linewidth=1.0,label='año 2021')
ax.plot(x2, y2, linewidth=1.0,label='año 2020')
ax.plot(x3, y3, linewidth=1.0,label='año 2019')
ax.plot(x4, y4, linewidth=1.0,label='año 2018')

ax.xaxis.set_tick_params(rotation=40)
ax.tick_params(grid_color='r', grid_alpha=0.1)


ax.xaxis.set_minor_locator(dates.MonthLocator(bymonthday=16))

ax.set_ylabel('Unidades')
ax.set_title('Movimiento Total')

plt.grid()
ax.legend()
plt.savefig("static\Años por colores.jpg")
plt.show()
