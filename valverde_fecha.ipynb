# %%
import pandas as pd

data = pd.read_csv('new_date.csv')
data.head()
# Out:
#          date  unidad
# 0  2018-01-01       8
# 1  2018-01-02     306
# 2  2018-01-03      88
# 3  2018-01-04     421
# 4  2018-01-05     210

# %%
data['date']
# Out:
# 0       2018-01-01
# 1       2018-01-02
# 2       2018-01-03
# 3       2018-01-04
# 4       2018-01-05
#            ...
# 1760    2022-10-27
# 1761    2022-10-28
# 1762    2022-10-29
# 1763    2022-10-30
# 1764    2022-10-31
# Name: date, Length: 1765, dtype: object

# %%
import matplotlib.pyplot as plt

y = data['unidad']
x = data['date']


fig, ax = plt.subplots(figsize=(15,6))
ax.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt



y = data['unidad']
x_todas = data['date']
x = []

for i in x_todas:
    if i < '2019-01-01' and i > '2018-01-01':
        x.append(i)

######################################

# falta flltrar

######################################



fig, ax = plt.subplots(figsize=(15,6))
ax.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [60], line 18
#      11         x.append(i)
#      17 fig, ax = plt.subplots(figsize=(15,6))
# ---> 18 ax.plot(x, y)
#      19 plt.show()
#
# File c:\Users\TEVA\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1635, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1393 """
#    1394 Plot y versus x as lines and/or markers.
#    1395
#    (...)
#    1632 (``'green'``) or hex strings (``'#008000'``).
#    1633 """
#    1634 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636 for line in lines:
#    1637     self.add_line(line)
#
# File c:\Users\TEVA\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
# ...
