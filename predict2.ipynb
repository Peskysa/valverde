# %%
import pandas as pd
df_160 = pd.read_excel('t_medio_año.xlsx')
df_160
# Out:
#           date  unidad
# 0   2022-05-02       1
# 1   2022-05-02      24
# 2   2022-05-02       8
# 3   2022-05-02       6
# 4   2022-05-02      44
# ..         ...     ...
# 873 2022-10-28       5
# 874 2022-10-28       7
# 875 2022-10-28     121
# 876 2022-10-30       1
# 877 2022-10-31       2
#
# [878 rows x 2 columns]

# %%
for i in df_160["date"]:
   

    if i == "2022-05-02 00:00:00":
        print(5)

    else: print(4444444444)
# Out:
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# 4444444444
# ...

# %%
df_160['date'] = pd.to_datetime(df_160['date'], format='%Y-%m-%d')

# Filter data between two dates
df_160_2018 = df_160.loc[(df_160['date'] >= '2022-05-01')
                     & (df_160['date'] < '2022-11-01')]
# Display
df_160_2018
# Out:
#                     date  unidad
# 4477 2022-05-02 00:00:00       1
# 4478 2022-05-02 15:00:00      24
# 4479 2022-05-02 17:00:00       8
# 4480 2022-05-02 20:00:00       6
# 4481 2022-05-02 22:00:00      44
# ...                  ...     ...
# 5350 2022-10-28 20:00:00       5
# 5351 2022-10-28 22:00:00       7
# 5352 2022-10-28 23:00:00     121
# 5353 2022-10-30 15:00:00       1
# 5354 2022-10-31 09:51:39       2
#
# [878 rows x 2 columns]
